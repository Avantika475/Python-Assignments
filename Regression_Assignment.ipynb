# %% [markdown]
# # **Regression Assignment Question**
#
# *Ques*.1 : what is simple linear regression ? & what is its purpose ?
#
# Ans :- Simple Linear Regression is a supervised learning algorithm used to find the relationship between two variables:
# Independent variable (X)  input or cause
#
# Dependent variable (Y)  output or effect
# It helps to predict the value of Y based on X.
#
# Purpose:-
#         1. To predict outcomes:
# For example :- predicting a person’s salary (Y) based on years of experience (X).
#
#
# 2. To find relationships between variables:
# Helps understand how one variable affects another (e.g., price vs. demand).
#
#
# 3. To make data-driven decisions:
# Businesses, economists, and data analysts use it for forecasting and trend analysis.
#
#
# 4. To build the base for advanced models:
# It’s the foundation for Multiple Linear Regression and other complex ML algorithms

# %% [markdown]
# *Ques.2* : what are the key assumption of simple linear regression ?
#
# *Ans* :- 1. Linearity
#
# The relationship between X (independent variable) and Y (dependent variable) must be linear.
#
# Meaning:- as X changes, Y changes in a roughly straight-line pattern.
#  Example: If hours studied increases, marks increase proportionally.
#
# 2. Independence of Errors
#
# The residuals (errors between predicted and actual values) must be independent of each other.
#
# No pattern should exist among errors.
#  Example: One error should not affect another otherwise, it shows correlation in residuals.
#
#  3. Homoscedasticity (Constant Variance of Errors)
#
# The variance of residuals should be constant across all levels of X.
#  If errors spread more at high X values, that means heteroscedasticity  which violates this assumption.
#
# 4. Normality of Errors
#
# The residuals should be normally distributed (bell-shaped curve).
#  Why?  This helps in making accurate confidence intervals and hypothesis tests.
#
# 5. No (or minimal) Multicollinearity
#
# In SLR, we use only one independent variable, so this is not a big issue.
#
# But if extended to Multiple Linear Regression, the independent variables should not be highly correlated with each other.
#
# 6. No significant Outliers
#
# Outliers (extreme values) can distort the regression line and give misleading results.
#
# So, data should be checked for outliers before fitting the model.

# %% [markdown]
# *Ques.3* :- What are the mathematical equation for simple linear regression model & Explain the term..?
#
# Ans :- 1. Dependent variable :- 	The variable we want to predict (also called the “response” or “target” variable). Example: Salary, Sales, etc.
#
# 	2. Independent variable	The variable used for prediction (also called the “predictor” or “feature”). Example: Experience, Advertising budget, etc.
#
# 	3. Intercept (constant term)	The value of  when . It represents where the regression line crosses the Y-axis.
#
# 	4. Slope coefficient	It shows how much  changes for a one-unit change in . Example: If , then for every 1 increase in ,  increases by 3 units.
#
# 	5. Error term (residual)	The difference between the actual and predicted value of . It captures all unexplained variation not predicted by.

# %% [markdown]
# *Ques.4* :- Provide the real world example where simple linear regression can be applied ?
#
# *Ans* :-
# 1. Predicting Salary based on Experience
#
# Independent variable (X): Years of Experience
#
# Dependent variable (Y): Employee Salary
#
# Use: Helps HR departments
#
# estimate how salary changes with each additional year of experience.
#
#
# 2. Predicting House Price from Size (Area)
#
# X: Square footage (size of house)
#
# Y: Price of house
#
# Use: Real estate analysts use it to estimate property values based on size.
#
# 3. Sales Prediction based on Advertising Spend
#
# X: Advertising budget (in ₹ or $)
#
# Y: Sales revenue
#
# Use: Marketing teams analyze how much sales increase for every extra rupee spent on ads.
#
# 4. Predicting Student Marks from Study Hours
#
# X: Hours studied per day
#
# Y: Exam score
#
# Use: Education researchers use it to understand how study time affects performance.
#
# 5. Predicting Crop Yield based on Rainfall
#
# X: Annual rainfall (in mm)
#
# Y: Crop yield (in tons)
#
# Use: Agriculture departments use it to forecast yield based on climatic factors.

# %% [markdown]
# *Ques.5* :- What is the methodb of least sqauare in linear regression ?
#
#
# *Ans* :- Method of Least Squares (in Linear Regression)
#
# The Method of Least Squares is a mathematical technique used to find the best-fitting line through a set of data points in Simple Linear Regression (SLR).
#
# Goal:
#
# To find the values of intercept (b₀) and slope (b₁) such that the sum of squared differences between actual and predicted values is minimum.

# %% [markdown]
# *Ques.6* :- What is logical regression ? How does it differs from linear regression ?
#
# *Ans* :- Logistic Regression is a supervised machine learning algorithm used when the dependent variable is categorical — most commonly binary (0 or 1).
#
# That means, it’s used for classification, not prediction of continuous values.
#
#  Example:
#
# Predict whether a person will buy a product → Yes (1) or No (0)
#
# Predict whether a student passes or fails → Pass (1) or Fail (0)
#
# Predict whether an email is spam or not → Spam (1) or Not spam (0)
#
# Purpose :-	Predicts a continuous output (e.g., salary, marks)	Predicts a categorical output (e.g., Yes/No, 0/1)
#
# Output Range :- 	Can be any real number (−∞ to +∞)	Output is probability between 0 and 1.
#
# Error Measure	Minimizes Sum of Squared Errors (SSE)	Uses Maximum Likelihood Estimation (MLE).
#
# Application Type	Used for Regression Problems	Used for Classification Problems.
#
# Example	Predicting house price, temperature, sales	Predicting disease presence, loan approval, churn

# %% [markdown]
# *Ques.7* :- Name & brifely describe the three common evaluation metrics for regression model ?
#
# *Ans* :- 1. Mean Absolute Error (MAE)
#
# Meaning:
#
# It measures the average absolute difference between actual values  and predicted values .
#
# It tells how far, on average, the predictions are from the actual data — without considering direction (positive/negative).
#
#  Interpretation:
#
# Lower MAE → better model
#
# Example: MAE = 5 means your predictions are off by 5 units on average.
#
# 2. Mean Squared Error (MSE)
# Meaning:
#
# It measures the average squared difference between actual and predicted values.
# Because of squaring, it penalizes larger errors more than smaller ones.
#
#  Interpretation:
#
# Smaller MSE → better model
#
# Useful when large errors are especially bad.
#
# 3. R-squared (R²) – Coefficient of Determination
#  Meaning:
#
# It shows how much of the variation in the dependent variable  is explained by the regression model.
#
#  Interpretation:
#
# : Perfect fit
#
# : Model explains nothing
#
# Example:  → 85% of the variance in Y is explained by the model

# %% [markdown]
# *Ques.8* :- What is the purpose of R-Squared metric in regression analysis ?
#
# *Ans* :- Purpose of R-Squared (R²) in Regression Analysis
#
# Definition:-
#
# R-Squared (R²), also called the coefficient of determination, is a statistical measure that shows how well the regression model explains the variation in the dependent variable (Y).
#
# Purpose:
#
# To measure the “goodness of fit” of a regression model
# how well the independent variable(s) explain or predict the dependent variable.
#
# > R² tells us how much of the variation in Y is explained by X.
#
# Interpretation:
#
# R² Value	Interpretation
#
# 0	Model explains none of the variation in Y
# 1	Model explains all the variation perfectly
# Between 0 and 1	Partial explanation — the closer to 1, the better the fit
#
#
# Example:
# If , that means 85% of the variation in the dependent variable is explained by the regression model, and 15% remains unexplained.

# %% [markdown]
# *Ques.9* :- write python code to fit a simple regression model using scitik-learn and print the slop & intercept ?
#
# (Include your python code & output in code box below)
#
# *Ans* :-

# %%
# Import necessary libraries
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data (X = independent variable, y = dependent variable)
X = np.array([[1], [2], [3], [4], [5]])   # Feature
y = np.array([2, 4, 5, 4, 5])             # Target

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Print the slope (coefficient) and intercept
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (Coefficient): 0.6
# Intercept: 2.2

# %% [markdown]
# *Ques.10* ;- How do you interpret the coefficient in a simple linear regression model..?
#
# *Ans* :- n a Simple Linear Regression (SLR) model, the relationship between a dependent variable
# 𝑌
# Y and an independent variable
# 𝑋
# X is expressed as:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜖
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ϵ
#
# Where:
#
# 𝛽
# 0
# β
# 0
# 	​
#
#  = Intercept (the value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0)
#
# 𝛽
# 1
# β
# 1
# 	​
#
#  = Slope or Coefficient of X
#
# 𝜖
# ϵ = Error term
#
# Interpretation of the Coefficient (
# β
# 1
# β
# 1
# ​
#  )
# The coefficient (
# β
# 1
# β
# 1
# ​
#  ) represents the average change in the dependent variable (Y) for a one-unit increase in the independent variable (X), keeping all else constant.
#
# In simpler words:
#
# If X increases by 1 unit, Y changes by β₁ units (increase if β₁ > 0, decrease if β₁ < 0).
